# %% [markdown]
# #### Line plot

# %%
# create a line plot
from pandas import read_csv
from matplotlib import pyplot

# %%
series = read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\daily-minimum-temperatures.csv',
                  header=0,
                  index_col=0,
                  parse_dates=True)
series.plot()
pyplot.show()

# %% [markdown]
# #### Histogram and Density Plots

# %%
# create a histogram plot
from pandas import read_csv
from matplotlib import pyplot

# %%
series = read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\daily-minimum-temperatures.csv',
                  header=0,
                  index_col=0,
                  parse_dates=True)
series.hist()
pyplot.show()

# %%
# create a density plot
from pandas import read_csv
from matplotlib import pyplot
series = read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\daily-minimum-temperatures.csv',
                  header=0,
                  index_col=0,
                  parse_dates=True)
series.plot(kind='kde')
pyplot.show()

# %% [markdown]
# #### Box and Whisker Plots by Interval

# %%
# create a boxplot of yearly data
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
series = read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\daily-minimum-temperatures.csv',
                  header=0,
                  index_col=0,
                  parse_dates=True)

series.boxplot()
pyplot.show()

# %% [markdown]
# #### Lag plot

# %%
# create a scatter plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import lag_plot
series = read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\daily-minimum-temperatures.csv',
                  header=0,
                  index_col=0,
                  parse_dates=True)
lag_plot(series)
pyplot.show()

# %%
# create an autocorrelation plot
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\daily-minimum-temperatures.csv',
                  header=0,
                  index_col=0,
                  parse_dates=True)
plot_acf(series,lags=30)
pyplot.show()
