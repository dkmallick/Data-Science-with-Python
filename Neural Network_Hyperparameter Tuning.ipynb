# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
dataset = np.loadtxt(r"C:\Users\lenovo\Desktop\ExcelR\CSV files\pima-indians-diabetes.csv", delimiter=",")
dataset
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -8.789266e-17 -9.251859e-18  1.503427e-17  8.211024e-17 -4.972874e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.960595e-15  1.905883e-15  2.081668e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END ..................batch_size=10, epochs=10; total time=   3.9s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END ..................batch_size=10, epochs=10; total time=   3.2s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END ..................batch_size=10, epochs=10; total time=   3.2s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END ..................batch_size=10, epochs=10; total time=   3.6s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END ..................batch_size=10, epochs=10; total time=   3.1s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END ..................batch_size=10, epochs=50; total time=   7.4s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END ..................batch_size=10, epochs=50; total time=   7.6s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END ..................batch_size=10, epochs=50; total time=   7.2s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END ..................batch_size=10, epochs=50; total time=   7.3s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END ..................batch_size=10, epochs=50; total time=   7.6s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END .................batch_size=10, epochs=100; total time=  12.6s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END .................batch_size=10, epochs=100; total time=  12.6s
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END .................batch_size=10, epochs=100; total time=  13.5s
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END .................batch_size=10, epochs=100; total time=  12.8s
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END .................batch_size=10, epochs=100; total time=  12.5s
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END ..................batch_size=20, epochs=10; total time=   2.7s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END ..................batch_size=20, epochs=10; total time=   3.0s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END ..................batch_size=20, epochs=10; total time=   2.6s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END ..................batch_size=20, epochs=10; total time=   2.6s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END ..................batch_size=20, epochs=10; total time=   2.9s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END ..................batch_size=20, epochs=50; total time=   4.8s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END ..................batch_size=20, epochs=50; total time=   5.1s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END ..................batch_size=20, epochs=50; total time=   5.5s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END ..................batch_size=20, epochs=50; total time=   5.4s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END ..................batch_size=20, epochs=50; total time=   5.2s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END .................batch_size=20, epochs=100; total time=   7.8s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END .................batch_size=20, epochs=100; total time=   7.8s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END .................batch_size=20, epochs=100; total time=   7.4s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END .................batch_size=20, epochs=100; total time=   7.4s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END .................batch_size=20, epochs=100; total time=   7.7s
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 1/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.4s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 2/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.4s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 3/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.7s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 4/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.4s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 5/5; 7/9] END ..................batch_size=40, epochs=10; total time=   2.4s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 1/5; 8/9] END ..................batch_size=40, epochs=50; total time=   3.6s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 2/5; 8/9] END ..................batch_size=40, epochs=50; total time=   4.0s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END ..................batch_size=40, epochs=50; total time=   3.6s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 4/5; 8/9] END ..................batch_size=40, epochs=50; total time=   3.7s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END ..................batch_size=40, epochs=50; total time=   4.0s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 1/5; 9/9] END .................batch_size=40, epochs=100; total time=   5.0s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 2/5; 9/9] END .................batch_size=40, epochs=100; total time=   5.0s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 3/5; 9/9] END .................batch_size=40, epochs=100; total time=   5.4s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 4/5; 9/9] END .................batch_size=40, epochs=100; total time=   5.1s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 5/5; 9/9] END .................batch_size=40, epochs=100; total time=   5.4s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7683558225631714, using {'batch_size': 20, 'epochs': 10}
# 0.7644172787666321,0.04633870202397639 with: {'batch_size': 10, 'epochs': 10}
# 0.7500806450843811,0.02976053046396306 with: {'batch_size': 10, 'epochs': 50}
# 0.7227145433425903,0.04993774991736961 with: {'batch_size': 10, 'epochs': 100}
# 0.7683558225631714,0.057712775957002374 with: {'batch_size': 20, 'epochs': 10}
# 0.7461251139640808,0.03921686173250407 with: {'batch_size': 20, 'epochs': 50}
# 0.7214413166046143,0.041273106015978576 with: {'batch_size': 20, 'epochs': 100}
# 0.765673553943634,0.03182788818487406 with: {'batch_size': 40, 'epochs': 10}
# 0.7487564802169799,0.029324294740012222 with: {'batch_size': 40, 'epochs': 50}
# 0.7305322289466858,0.02871420587895896 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# %%
# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# %%
# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# %%
# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 1/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   3.3s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   2.6s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   2.9s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   3.8s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 5/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   3.1s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 1/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.1s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 2/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.1s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 3/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.5s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 4/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.0s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 5/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   3.0s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 1/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.5s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 2/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.0s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 3/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.1s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 4/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.6s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 5/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   3.1s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 1/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.1s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 2/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.1s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 3/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.5s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 4/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.1s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 5/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   3.0s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   3.5s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   3.0s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   3.2s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   3.7s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   4.3s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   3.2s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   2.8s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   3.3s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   2.8s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   2.8s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 1/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   2.8s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 2/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   3.2s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 3/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   2.8s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 4/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   2.8s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 5/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   2.9s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.8s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.1s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.1s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.0s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   3.6s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.0s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.0s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.0s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.6s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   3.1s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7683049082756043, using {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7045157551765442,0.07129716109328052 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7683049082756043,0.03287752163636616 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.748773455619812,0.04901191113714688 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7436125993728637,0.0505741783671165 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7605126976966858,0.04239149177079487 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7513963103294372,0.06305635743404087 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7202529549598694,0.06750928772410868 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7682964086532593,0.036615842696788255 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7474492907524108,0.026634958797672127 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform; total time=   3.0s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform; total time=   3.3s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform; total time=   2.9s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform; total time=   2.9s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform; total time=   2.8s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 1/5; 2/12] END .activation_function=softmax, init=normal; total time=   3.2s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 2/5; 2/12] END .activation_function=softmax, init=normal; total time=   2.8s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 3/5; 2/12] END .activation_function=softmax, init=normal; total time=   2.7s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 4/5; 2/12] END .activation_function=softmax, init=normal; total time=   3.3s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 5/5; 2/12] END .activation_function=softmax, init=normal; total time=   2.8s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 1/5; 3/12] END ...activation_function=softmax, init=zero; total time=   3.0s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 2/5; 3/12] END ...activation_function=softmax, init=zero; total time=   2.8s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 3/5; 3/12] END ...activation_function=softmax, init=zero; total time=   2.8s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 4/5; 3/12] END ...activation_function=softmax, init=zero; total time=   3.3s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 5/5; 3/12] END ...activation_function=softmax, init=zero; total time=   2.7s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 1/5; 4/12] END ...activation_function=relu, init=uniform; total time=   2.7s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 2/5; 4/12] END ...activation_function=relu, init=uniform; total time=   2.7s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 3/5; 4/12] END ...activation_function=relu, init=uniform; total time=   3.2s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 4/5; 4/12] END ...activation_function=relu, init=uniform; total time=   2.7s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 5/5; 4/12] END ...activation_function=relu, init=uniform; total time=   2.7s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# [CV 1/5; 5/12] END ....activation_function=relu, init=normal; total time=   2.8s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# [CV 2/5; 5/12] END ....activation_function=relu, init=normal; total time=   3.3s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# [CV 3/5; 5/12] END ....activation_function=relu, init=normal; total time=   3.2s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# [CV 4/5; 5/12] END ....activation_function=relu, init=normal; total time=   2.9s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# [CV 5/5; 5/12] END ....activation_function=relu, init=normal; total time=   2.7s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# [CV 1/5; 6/12] END ......activation_function=relu, init=zero; total time=   2.7s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# [CV 2/5; 6/12] END ......activation_function=relu, init=zero; total time=   3.2s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# [CV 3/5; 6/12] END ......activation_function=relu, init=zero; total time=   2.7s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# [CV 4/5; 6/12] END ......activation_function=relu, init=zero; total time=   2.7s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# [CV 5/5; 6/12] END ......activation_function=relu, init=zero; total time=   2.7s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 1/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   3.3s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 2/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   2.7s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 3/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   2.7s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 4/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   2.7s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 5/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   2.7s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 1/5; 8/12] END ....activation_function=tanh, init=normal; total time=   3.4s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 2/5; 8/12] END ....activation_function=tanh, init=normal; total time=   2.8s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 3/5; 8/12] END ....activation_function=tanh, init=normal; total time=   2.7s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 4/5; 8/12] END ....activation_function=tanh, init=normal; total time=   2.7s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 5/5; 8/12] END ....activation_function=tanh, init=normal; total time=   3.2s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 1/5; 9/12] END ......activation_function=tanh, init=zero; total time=   2.8s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 2/5; 9/12] END ......activation_function=tanh, init=zero; total time=   2.9s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 3/5; 9/12] END ......activation_function=tanh, init=zero; total time=   2.7s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 4/5; 9/12] END ......activation_function=tanh, init=zero; total time=   2.8s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 5/5; 9/12] END ......activation_function=tanh, init=zero; total time=   3.6s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 1/5; 10/12] END activation_function=linear, init=uniform; total time=   2.8s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform; total time=   2.8s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 3/5; 10/12] END activation_function=linear, init=uniform; total time=   2.8s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 4/5; 10/12] END activation_function=linear, init=uniform; total time=   2.6s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 5/5; 10/12] END activation_function=linear, init=uniform; total time=   3.3s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# [CV 1/5; 11/12] END .activation_function=linear, init=normal; total time=   2.7s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# [CV 2/5; 11/12] END .activation_function=linear, init=normal; total time=   2.7s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# [CV 3/5; 11/12] END .activation_function=linear, init=normal; total time=   2.6s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# [CV 4/5; 11/12] END .activation_function=linear, init=normal; total time=   3.2s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# [CV 5/5; 11/12] END .activation_function=linear, init=normal; total time=   2.6s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 1/5; 12/12] END ...activation_function=linear, init=zero; total time=   2.6s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 2/5; 12/12] END ...activation_function=linear, init=zero; total time=   2.6s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 3/5; 12/12] END ...activation_function=linear, init=zero; total time=   2.6s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 4/5; 12/12] END ...activation_function=linear, init=zero; total time=   3.3s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 5/5; 12/12] END ...activation_function=linear, init=zero; total time=   2.7s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.763144052028656, using {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.7565656661987304,0.03143571726603502 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.7357270240783691,0.03158433167425007 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7514132976531982,0.045903567350794705 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.763144052028656,0.04756584272502995 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7553348779678345,0.051780663373889556 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7513963222503662,0.03790031259629218 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.7s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.7s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   3.3s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.8s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   2.8s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.7s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.7s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.7s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   3.4s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   2.7s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.7s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.7s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.7s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   3.3s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.7s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.7s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.7s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.7s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   3.3s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   2.7s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.7s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.7s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.7s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   3.4s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   2.7s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.7s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.7s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.7s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   2.7s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   3.4s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.7s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.7s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.7s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.7s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   2.7s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   3.4s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.7s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.7s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.7s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   2.8s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   3.5s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   2.9s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   3.0s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   2.7s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   2.8s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7695951104164124, using {'neuron1': 16, 'neuron2': 8}
# 0.7331465959548951,0.03744961123005597 with: {'neuron1': 4, 'neuron2': 2}
# 0.7448773503303527,0.040097777410468285 with: {'neuron1': 4, 'neuron2': 4}
# 0.7553009033203125,0.04711469850466015 with: {'neuron1': 4, 'neuron2': 8}
# 0.7514048099517823,0.04520537470986149 with: {'neuron1': 8, 'neuron2': 2}
# 0.7591970086097717,0.03899232041312674 with: {'neuron1': 8, 'neuron2': 4}
# 0.7657244682312012,0.0452019434489688 with: {'neuron1': 8, 'neuron2': 8}
# 0.7683133840560913,0.03763707854139341 with: {'neuron1': 16, 'neuron2': 2}
# 0.764408802986145,0.037784238450161926 with: {'neuron1': 16, 'neuron2': 4}
# 0.7695951104164124,0.02941067319715866 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# WARNING:tensorflow:From C:\Users\lenovo\anaconda3\envs\Tensorflow\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py:241: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# 0.78125
